# %% [markdown]
# <a href="https://colab.research.google.com/github/Hannicko/subject101/blob/main/exer2_VENANCIO_BSCS_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. creating dataset

# %%
import pandas as pd

data = {
    'student_id': range(1,16),
    'gender':["", 'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male'],
    'test_date': pd.date_range(start = '2024-02-14', periods=15),
    'study_hours':[8,5,5,2,6,3,1,5,3,4,2,4,6,4,5],
    'test_score': [90,80,93,98,75,83,85,90,93,90,82,87,90,93,90],
    'attendance': ['present', 'present', 'present', 'present', 'present', 'present', 'present', 'absent', 'present', 'present', 'present', 'absent', 'present', 'absent', 'present'],
}

df = pd.DataFrame(data)

df.to_csv('student_performance.csv', index=False)

# %% [markdown]
# #2. Data loading and Initial Examination

# %%
df = pd.read_csv('student_performance.csv')

print(df.head(10))

print(df.isnull().sum())
# Out:
#    student_id  gender   test_date  study_hours  test_score attendance
# 0           1     NaN  2024-02-14            5          80    present
# 1           2    Male  2024-02-15            2          75    present
# 2           3  Female  2024-02-16            5          87    present
# 3           4    Male  2024-02-17            2          98    present
# 4           5    Male  2024-02-18            6          75    present
# 5           6  Female  2024-02-19            3          83    present
# 6           7    Male  2024-02-20            1          87    present
# 7           8    Male  2024-02-21            5          90     absent
# 8           9    Male  2024-02-22            3          93    present
# 9          10    Male  2024-02-23            4          90    present
# student_id     0
# gender         1
# test_date      0
# study_hours    0
# test_score     0
# attendance     0
# dtype: int64

# %% [markdown]
# 3. Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sne

summary_stats = df[['test_score','study_hours']].describe()

#Histogram
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sne.histplot(df['test_score'],bins=15,kde=True)
plt.title('Distribution of Test Score')

plt.subplot(1,2,2)
sne.scatterplot(data=df,x='study_hours',y="test_score")
plt.title("Scatter Plot of Study Gours Vs. Test Scores")

#Scatterplot
plt.figure(figsize=(12,6))
sne.scatterplot(data=df, x="study_hours", y="test_score")
plt.title("Scatter Plot of Study Hours vs. Test Scores")

correlation_matrix = df[["study_hours", "test_score", "attendance"]].corr()
plt.figure(figsize=(12,6))
sne.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
# Out:
# <ipython-input-24-ec8f2561c685>:22: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[["study_hours", "test_score", "attendance"]].corr()
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# 4. Data Visualization

# %%
plt.figure(figsize = (12,6))
sne.countplot(data=df, x="gender")
plt.title("Gender Distribution")

plt.figure(figsize=(12,6))
sne.lineplot(data=df,x="test_date", y="test_score")
# Out:
# <Axes: xlabel='test_date', ylabel='test_score'>

# %% [markdown]
# 5. Reports

# %%
print(summary_stats)
# Out:
#        test_score  study_hours
# count   15.000000    15.000000
# mean    87.933333     3.800000
# std      5.969765     1.567528
# min     75.000000     1.000000
# 25%     84.000000     2.500000
# 50%     90.000000     4.000000
# 75%     91.500000     5.000000
# max     98.000000     6.000000
